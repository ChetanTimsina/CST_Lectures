# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.9.1'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()
# Out:
# 2024-10-31 09:18:32.646809: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 10)
# Out:
# Epoch 1/10
# 250/250 [==============================] - 27s 106ms/step - loss: 0.6719 - accuracy: 0.5941 - val_loss: 0.6406 - val_accuracy: 0.6370
# Epoch 2/10
# 250/250 [==============================] - 25s 101ms/step - loss: 0.6140 - accuracy: 0.6643 - val_loss: 0.5874 - val_accuracy: 0.6900
# Epoch 3/10
# 250/250 [==============================] - 26s 103ms/step - loss: 0.5729 - accuracy: 0.6963 - val_loss: 0.5437 - val_accuracy: 0.7325
# Epoch 4/10
# 250/250 [==============================] - 25s 101ms/step - loss: 0.5330 - accuracy: 0.7281 - val_loss: 0.5075 - val_accuracy: 0.7505
# Epoch 5/10
# 250/250 [==============================] - 26s 103ms/step - loss: 0.5152 - accuracy: 0.7456 - val_loss: 0.4939 - val_accuracy: 0.7575
# Epoch 6/10
# 250/250 [==============================] - 25s 101ms/step - loss: 0.4828 - accuracy: 0.7645 - val_loss: 0.5075 - val_accuracy: 0.7570
# Epoch 7/10
# 250/250 [==============================] - 25s 101ms/step - loss: 0.4670 - accuracy: 0.7759 - val_loss: 0.4753 - val_accuracy: 0.7745
# Epoch 8/10
# 250/250 [==============================] - 26s 103ms/step - loss: 0.4556 - accuracy: 0.7811 - val_loss: 0.4788 - val_accuracy: 0.7720
# Epoch 9/10
# 250/250 [==============================] - 25s 101ms/step - loss: 0.4399 - accuracy: 0.7926 - val_loss: 0.4825 - val_accuracy: 0.7690
# Epoch 10/10
# 250/250 [==============================] - 25s 101ms/step - loss: 0.4238 - accuracy: 0.8026 - val_loss: 0.4782 - val_accuracy: 0.7775

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 128)               802944
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 813,217
# Trainable params: 813,217
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Saving trained model

# %%
cnn.save('my_model.keras')

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np
#from keras.preprocessing import image
from keras.utils import load_img, img_to_array
test_image = load_img('dataset/single_prediction/cat_or_dog_2.jpg', target_size = (64, 64))
test_image = img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 [==============================] - 0s 12ms/step

# %%
print(prediction)
# Out:
# cat

# %% [markdown]
# # Loading and using the saved model

# %%
new_model = tf.keras.models.load_model('my_model.keras')
# Show the model architecture
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 128)               802944
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 813,217
# Trainable params: 813,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np
#from keras.preprocessing import image
from keras.utils import load_img, img_to_array
test_image = load_img('dataset/single_prediction/cat_or_dog_2.jpg', target_size = (64, 64))
test_image = img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = new_model.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 [==============================] - 0s 34ms/step

# %%
print(prediction)
# Out:
# cat
